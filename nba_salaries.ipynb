# %%
pip install datascience
# Out:
# Requirement already satisfied: datascience in ./opt/anaconda3/lib/python3.9/site-packages (0.17.0)
# Requirement already satisfied: branca in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.4.2)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.3.4)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (58.0.4)
# Requirement already satisfied: pytest in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (6.2.4)
# Requirement already satisfied: ipython in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (7.29.0)
# Requirement already satisfied: matplotlib>=3.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (3.4.3)
# Requirement already satisfied: folium>=0.9.1 in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.12.1.post1)
# Requirement already satisfied: scipy in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.7.1)
# Requirement already satisfied: sphinx in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (4.2.0)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.20.3)
# Requirement already satisfied: coveralls in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (3.3.1)
# Requirement already satisfied: plotly in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (5.5.0)
# Requirement already satisfied: bokeh in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (2.4.1)
# Requirement already satisfied: nbsphinx in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.8.8)
# Requirement already satisfied: coverage in ./opt/anaconda3/lib/python3.9/site-packages (from datascience) (6.2)
# Requirement already satisfied: jinja2>=2.9 in ./opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (2.11.3)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (2.26.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (8.4.0)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.0.0->datascience) (1.16.0)
# Requirement already satisfied: tornado>=5.1 in ./opt/anaconda3/lib/python3.9/site-packages (from bokeh->datascience) (6.1)
# Requirement already satisfied: packaging>=16.8 in ./opt/anaconda3/lib/python3.9/site-packages (from bokeh->datascience) (21.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from bokeh->datascience) (3.10.0.2)
# Requirement already satisfied: PyYAML>=3.10 in ./opt/anaconda3/lib/python3.9/site-packages (from bokeh->datascience) (6.0)
# Requirement already satisfied: docopt>=0.6.1 in ./opt/anaconda3/lib/python3.9/site-packages (from coveralls->datascience) (0.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (3.2)
# Requirement already satisfied: decorator in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.1.0)
# Requirement already satisfied: matplotlib-inline in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: backcall in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.18.0)
# Requirement already satisfied: pygments in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (2.10.0)
# Requirement already satisfied: pickleshare in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.1.0)
# Requirement already satisfied: appnope in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in ./opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->datascience) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->datascience) (0.7.0)
# Requirement already satisfied: wcwidth in ./opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.5)
# Requirement already satisfied: nbformat in ./opt/anaconda3/lib/python3.9/site-packages (from nbsphinx->datascience) (5.1.3)
# Requirement already satisfied: nbconvert!=5.4 in ./opt/anaconda3/lib/python3.9/site-packages (from nbsphinx->datascience) (6.1.0)
# Requirement already satisfied: docutils in ./opt/anaconda3/lib/python3.9/site-packages (from nbsphinx->datascience) (0.17.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.3)
# Requirement already satisfied: defusedxml in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.8.4)
# Requirement already satisfied: testpath in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.5.0)
# Requirement already satisfied: jupyter-core in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (4.8.1)
# Requirement already satisfied: bleach in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./opt/anaconda3/lib/python3.9/site-packages (from nbconvert!=5.4->nbsphinx->datascience) (1.4.3)
# Requirement already satisfied: jupyter-client>=6.1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (6.1.12)
# Requirement already satisfied: async-generator in ./opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (1.10)
# Requirement already satisfied: nest-asyncio in ./opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in ./opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (22.2.1)
# Requirement already satisfied: ipython-genutils in ./opt/anaconda3/lib/python3.9/site-packages (from nbformat->nbsphinx->datascience) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./opt/anaconda3/lib/python3.9/site-packages (from nbformat->nbsphinx->datascience) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in ./opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience) (21.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (2.1.0)
# Requirement already satisfied: babel>=1.3 in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (2.9.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (0.7.12)
# Requirement already satisfied: imagesize in ./opt/anaconda3/lib/python3.9/site-packages (from sphinx->datascience) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in ./opt/anaconda3/lib/python3.9/site-packages (from babel>=1.3->sphinx->datascience) (2021.3)
# Requirement already satisfied: webencodings in ./opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert!=5.4->nbsphinx->datascience) (0.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from plotly->datascience) (8.0.1)
# Requirement already satisfied: iniconfig in ./opt/anaconda3/lib/python3.9/site-packages (from pytest->datascience) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in ./opt/anaconda3/lib/python3.9/site-packages (from pytest->datascience) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in ./opt/anaconda3/lib/python3.9/site-packages (from pytest->datascience) (1.10.0)
# Requirement already satisfied: toml in ./opt/anaconda3/lib/python3.9/site-packages (from pytest->datascience) (0.10.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datascience import *
import numpy as mo

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
NBA=Table.read_table('NBA_Salaries.csv')
NBA
# Out:
# PLAYER           | POSITION | TEAM          | '15-'16 SALARY
# Paul Millsap     | PF       | Atlanta Hawks | 18.6717
# Al Horford       | C        | Atlanta Hawks | 12
# Tiago Splitter   | C        | Atlanta Hawks | 9.75625
# Jeff Teague      | PG       | Atlanta Hawks | 8
# Kyle Korver      | SG       | Atlanta Hawks | 5.74648
# Thabo Sefolosha  | SF       | Atlanta Hawks | 4
# Mike Scott       | PF       | Atlanta Hawks | 3.33333
# Kent Bazemore    | SF       | Atlanta Hawks | 2
# Dennis Schroder  | PG       | Atlanta Hawks | 1.7634
# Tim Hardaway Jr. | SG       | Atlanta Hawks | 1.30452
# ... (407 rows omitted)

# %%
NBA.sort('PLAYER')
# Out:
# PLAYER          | POSITION | TEAM                   | '15-'16 SALARY
# Aaron Brooks    | PG       | Chicago Bulls          | 2.25
# Aaron Gordon    | PF       | Orlando Magic          | 4.17168
# Aaron Harrison  | SG       | Charlotte Hornets      | 0.525093
# Adreian Payne   | PF       | Minnesota Timberwolves | 1.93884
# Al Horford      | C        | Atlanta Hawks          | 12
# Al Jefferson    | C        | Charlotte Hornets      | 13.5
# Al-Farouq Aminu | SF       | Portland Trail Blazers | 8.04289
# Alan Anderson   | SG       | Washington Wizards     | 4
# Alec Burks      | SG       | Utah Jazz              | 9.46348
# Alex Len        | C        | Phoenix Suns           | 3.80712
# ... (407 rows omitted)

# %%
NBA.sort('POSITION')
# Out:
# PLAYER             | POSITION | TEAM              | '15-'16 SALARY
# Al Horford         | C        | Atlanta Hawks     | 12
# Tiago Splitter     | C        | Atlanta Hawks     | 9.75625
# Walter Tavares     | C        | Atlanta Hawks     | 1
# Tyler Zeller       | C        | Boston Celtics    | 2.61698
# Jared Sullinger    | C        | Boston Celtics    | 2.56926
# Kelly Olynyk       | C        | Boston Celtics    | 2.16516
# Andrea Bargnani    | C        | Brooklyn Nets     | 1.3629
# Al Jefferson       | C        | Charlotte Hornets | 13.5
# Cody Zeller        | C        | Charlotte Hornets | 4.2042
# Frank Kaminsky III | C        | Charlotte Hornets | 2.61252
# ... (407 rows omitted)

# %%
import pandas as pd
from IPython.display import display

df = pd.read_csv("NBA_Salaries.csv")
pd.options.display.max_columns = None
display(df)
# Out:
#               PLAYER POSITION                TEAM  '15-'16 SALARY
# 0       Paul Millsap       PF       Atlanta Hawks       18.671659
# 1         Al Horford        C       Atlanta Hawks       12.000000
# 2     Tiago Splitter        C       Atlanta Hawks        9.756250
# 3        Jeff Teague       PG       Atlanta Hawks        8.000000
# 4        Kyle Korver       SG       Atlanta Hawks        5.746479
# ..               ...      ...                 ...             ...
# 412        Gary Neal       PG  Washington Wizards        2.139000
# 413     DeJuan Blair        C  Washington Wizards        2.000000
# 414  Kelly Oubre Jr.       SF  Washington Wizards        1.920240
# 415   Garrett Temple       SG  Washington Wizards        1.100602
# 416     Jarell Eddie       SG  Washington Wizards        0.561716
#
# [417 rows x 4 columns]

# %%
point_guards = NBA.where('POSITION', 'PG')
point_guards
# Out:
# PLAYER          | POSITION | TEAM              | '15-'16 SALARY
# Jeff Teague     | PG       | Atlanta Hawks     | 8
# Dennis Schroder | PG       | Atlanta Hawks     | 1.7634
# Avery Bradley   | PG       | Boston Celtics    | 7.73034
# Isaiah Thomas   | PG       | Boston Celtics    | 6.91287
# Marcus Smart    | PG       | Boston Celtics    | 3.43104
# Terry Rozier    | PG       | Boston Celtics    | 1.82436
# Jarrett Jack    | PG       | Brooklyn Nets     | 6.3
# Shane Larkin    | PG       | Brooklyn Nets     | 1.5
# Kemba Walker    | PG       | Charlotte Hornets | 12
# Brian Roberts   | PG       | Charlotte Hornets | 2.85494
# ... (75 rows omitted)

# %%
NBA.drop('POSITION')
# Out:
# PLAYER           | TEAM          | '15-'16 SALARY
# Paul Millsap     | Atlanta Hawks | 18.6717
# Al Horford       | Atlanta Hawks | 12
# Tiago Splitter   | Atlanta Hawks | 9.75625
# Jeff Teague      | Atlanta Hawks | 8
# Kyle Korver      | Atlanta Hawks | 5.74648
# Thabo Sefolosha  | Atlanta Hawks | 4
# Mike Scott       | Atlanta Hawks | 3.33333
# Kent Bazemore    | Atlanta Hawks | 2
# Dennis Schroder  | Atlanta Hawks | 1.7634
# Tim Hardaway Jr. | Atlanta Hawks | 1.30452
# ... (407 rows omitted)

# %%
point_guards.sort("'15-'16 SALARY")
# Out:
# PLAYER          | POSITION | TEAM                 | '15-'16 SALARY
# Phil Pressey    | PG       | Phoenix Suns         | 0.055722
# Keith Appling   | PG       | Orlando Magic        | 0.061776
# Erick Green     | PG       | Utah Jazz            | 0.099418
# Lorenzo Brown   | PG       | Phoenix Suns         | 0.111444
# Corey Hawkins   | PG       | Miami Heat           | 0.525093
# Bo McCalebb     | PG       | New Orleans Pelicans | 0.525093
# Shannon Scott   | PG       | Toronto Raptors      | 0.525093
# Bryce Cotton    | PG       | Phoenix Suns         | 0.700902
# Russ Smith      | PG       | Memphis Grizzlies    | 0.845059
# Jimmer Fredette | PG       | New York Knicks      | 0.874837
# ... (75 rows omitted)

# %%
NBA.where('TEAM', 'Golden State Warriors')
# Out:
# PLAYER            | POSITION | TEAM                  | '15-'16 SALARY
# Klay Thompson     | SG       | Golden State Warriors | 15.501
# Draymond Green    | PF       | Golden State Warriors | 14.2609
# Andrew Bogut      | C        | Golden State Warriors | 13.8
# Andre Iguodala    | SF       | Golden State Warriors | 11.7105
# Stephen Curry     | PG       | Golden State Warriors | 11.3708
# Jason Thompson    | PF       | Golden State Warriors | 7.00847
# Shaun Livingston  | PG       | Golden State Warriors | 5.54373
# Harrison Barnes   | SF       | Golden State Warriors | 3.8734
# Marreese Speights | C        | Golden State Warriors | 3.815
# Leandro Barbosa   | SG       | Golden State Warriors | 2.5
# ... (4 rows omitted)
